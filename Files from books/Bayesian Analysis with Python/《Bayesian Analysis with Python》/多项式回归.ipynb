# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pymc3 as pm
import numpy as np

# %%
#加载数据
ans = sns.load_dataset('anscombe')
x2 = ans[ans.dataset == 'II']['x'].values
y2 = ans[ans.dataset == 'II']['y'].values
#数据中心化
x2 = x2 - x2.mean()
y2 = y2 - y2.mean()
#可视化
plt.scatter(x2, y2)
plt.xlabel('$x$')
plt.ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
x_p = np.linspace(-6, 6)
y_p = trace['alpha'].mean() + trace['beta1'].mean() * x_p \
      + trace['beta2'].mean() * x_p**2
plt.scatter(x2, y2)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.plot(x_p, y_p, c='r')
